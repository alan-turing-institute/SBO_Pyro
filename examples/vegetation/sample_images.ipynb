# %%
# Import pyveg
from pyveg.scripts.optimize_gee_threshold import optimize_threshold

# %%
optimize_threshold(150)
# Out:
# Processing the time period between 2016-03-30 and 2016-04-14
# [[27.9, 11.620000000000001], [28.0, 11.620000000000001], [28.0, 11.52], [27.9, 11.52]]
# Found 1 sets of images for coords [27.95, 11.57]
# Found image of size (1114, 1114)
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.522_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.527_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.531_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.536_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.540_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.545_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.550_2016-04-06.png
# Saved image /tmp/optimize_150/34e9504ab5afb4309d2016510d81309a_27.902_11.554_2016-04-06.png
# ...

# %%
optimize_threshold(600)
# Out:
# Processing the time period between 2016-03-30 and 2016-04-14
# [[27.9, 11.620000000000001], [28.0, 11.620000000000001], [28.0, 11.52], [27.9, 11.52]]
# Found 1 sets of images for coords [27.95, 11.57]
# Found image of size (1114, 1114)
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.522_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.527_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.531_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.536_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.540_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.545_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.550_2016-04-06.png
# Saved image /tmp/optimize_600/6009d5e7499affbef57f66fcfc834455_27.902_11.554_2016-04-06.png
# ...

# %%
optimize_threshold(550)
# Out:
# Processing the time period between 2016-03-30 and 2016-04-14
# [[27.9, 11.620000000000001], [28.0, 11.620000000000001], [28.0, 11.52], [27.9, 11.52]]
# Found 1 sets of images for coords [27.95, 11.57]
# Found image of size (1114, 1114)
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.522_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.527_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.531_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.536_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.540_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.545_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.550_2016-04-06.png
# Saved image /tmp/optimize_550/0bd50b88ba726396cd9054f1aebd5f80_27.902_11.554_2016-04-06.png
# ...

# %%
optimize_threshold(350)
# Out:
# Processing the time period between 2016-03-30 and 2016-04-14
# [[27.9, 11.620000000000001], [28.0, 11.620000000000001], [28.0, 11.52], [27.9, 11.52]]
# Found 1 sets of images for coords [27.95, 11.57]
# Found image of size (1114, 1114)
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.522_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.527_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.531_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.536_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.540_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.545_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.550_2016-04-06.png
# Saved image /tmp/optimize_350/d13c5cbd9c03958c215969c294e00e68_27.902_11.554_2016-04-06.png
# ...
